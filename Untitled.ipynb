# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from utils import *

# %%
df_for_testing = pd.read_csv('./train.csv')

# %%
df_for_testing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df_for_testing.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
n_variables = 2

# %%
variables = [df_for_testing.columns[2],df_for_testing.columns[5]]
v = [0]*n_variables

# %%
dict[n_variables]
# Out:
# ('Line plot', 'Scatter plot', 'Boxplot', 'Stacked area chart', 'Heatmap')

# %%
func = dict[n_variables][-1]

# %%
func
# Out:
# 'Heatmap'

# %%
f = var_func_dict[n_variables]
s = f[func]
s
# Out:
# <function utils.htm(df, v1, v2)>

# %%
v1,v2 = variables[0],variables[1]

# %%
dfh =pd.DataFrame(df_for_testing[v2],index=df_for_testing[v1].values)

# %%
dfh
# Out:
#      Age
# 3   35.0
# 1   38.0
# 3   35.0
# 1   38.0
# 3   35.0
# ..   ...
# 2   26.0
# 1   38.0
# 3   35.0
# 1   38.0
# 3   35.0
#
# [891 rows x 1 columns]

# %%
sns.heatmap(df_for_testing[[v1,v2]], annot=True, fmt=".1f")
# Out:
# <Axes: >

# %%
s(df_for_testing[variables])

# %%
fig, ax = plt.subplots()
ax = s(df_for_testing[[variables]])
plt.show()
